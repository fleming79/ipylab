# %% [markdown]
# **To use this notebook:** Run one line at a time waiting for each cell to return before running the next cell.

# %% [markdown]
# # Command Registry

# %%
# %pip install -q ipylab

# %%
import asyncio

import ipywidgets as ipw

import ipylab

app = ipylab.App()
app.commands

# %%
app.version

# %% [markdown]
# ## List all commands

# %%
app.commands.all_commands

# %% [markdown]
# ## Create a new console

# %%
t = app.commands.execute("console:create", {"insertMode": "split-right", "path": app.vpath})

# %%
w = t.result()

# %%
w.close(dispose=True)

# %% [markdown]
# ## Change the theme

# %%
app.commands.execute("apputils:change-theme", {"theme": "JupyterLab Dark"})

# %%
app.commands.execute("apputils:change-theme", {"theme": "JupyterLab Light"})

# %% [markdown]
# ## Add your own command
#
# Let's create a split panel and add a command to toggle the orientation.

# %%
split_panel = ipylab.SplitPanel(children=[ipw.Button(description="Item A"), ipw.Button(description="Item B")])
split_panel.add_to_shell(mode=ipylab.InsertMode.split_right)

# %% [markdown]
# We now define a function to update the data.

# %%
def toggle_orientation():
    split_panel.orientation = next(iter({"horizontal", "vertical"}.difference((split_panel.orientation,))))
    split_panel.title.label = split_panel.orientation
    return "Data returned from this custom function 'toggle_orientation'"

# %%
toggle_orientation()

# %% [markdown]
# This function will now be called when the JupyterLab command is executed.
#
# > Commands can also custom [icons](./icons.ipynb) in place of `icon_class`.

# %%
t = app.commands.add(
    "swap_orientation", execute=toggle_orientation, label="Swap orientation", icon_class="jp-PythonIcon"
)

# %% [markdown]
# Execute it!

# %%
cmd = t.result()
app.commands.execute("swap_orientation")

# %% [markdown]
# We can also use the command to execute (via the frontend).

# %%
t = cmd.execute()

# %% [markdown]
# Though normally we'd just call the function directly.

# %%
cmd.python_command()

# %% [markdown]
# Notice how the orientation switched?
#
# Also we can get the result from the operation:

# %%
t.result()

# %% [markdown]
# The message has taken the follow steps to get the result:
#
# 1. Python -> JavaScript : commands.execute `ipylab-CommandConnection|Jupyterlab|swap_orientation`
# 2. JavaScript -> Python : _do_operation_for_frontend 'execute' `ipylab-CommandConnection|Jupyterlab|swap_orientation`
# 3. Python -> JavaScript : Return the result
# 4. JavaScript -> Python : Return the result
#
# Also the list of commands gets updated with the newly added command:

# %%
assert str(cmd) in app.commands.all_commands  # noqa: S101
# Note the command id is the 'cid' of the CommandConnection.
str(cmd)

# %% [markdown]
# ### Add the command to the [command palette](https://jupyterlab.readthedocs.io/en/latest/user/commands.html#command-palette)
#
# Let's add the command to the command pallet!

# %%
t = app.command_pallet.add(cmd, "All Python Commands")

# %%
pc = t.result()

# %%
pc

# %% [markdown]
# Open the command palette (CTRL + SHIFT + C) and the command should show now be visible. Look for `Swap orientation`

# %%
def show_command_pallet():
    # Use a delay to the call so the command pallet remains open.
    asyncio.get_running_loop().call_later(1, app.commands.execute, "apputils:activate-command-palette")


show_command_pallet()

# %% [markdown]
# ## Launcher

# %%
t = app.launcher.add(cmd, "My command")

# %%
launcher = t.result()

# %% [markdown]
# Notice that a launcher button exists for this command?

# %%
app.commands.execute("launcher:create")

# %%
launcher.close(dispose=True)

# %% [markdown]
# These methods are provided on the command connection:
#
# * add_to_command_pallet
# * add launcher
#
# They will close (dispose) when the command connection is closed.

# %% [markdown]
# ## Configure a command
#
# The command can be configured on demand by using the `configure` method on the `CommandConnection` object.

# %%
import ipylab.commands

list(ipylab.commands.CommandOptions.__annotations__)

# %% [markdown]
# To disable a command

# %%
t = cmd.configure(isEnabled=False)

# %%
# The current configuration is in the response
t.result()

# %%
show_command_pallet()

# %% [markdown]
# Notice the command is not in the pallet.

# %%
t = cmd.configure(isEnabled=True)

# %%
show_command_pallet()

# %% [markdown]
# Again the command is again available in the pallet.

# %%
# The config
t.result()

# %% [markdown]
# ## Remove a command by name

# %%
assert str(cmd) in app.commands.all_commands  # noqa: S101

# %%
app.commands.remove("swap_orientation")
# or just call dispose on the connection.
cmd.close(dispose=True)

# %%
assert str(cmd) not in app.commands.all_commands  # noqa: S101

# %%
commands = ipylab.commands.CommandRegistry(name="alternate commands")

# %%
t = commands.add("Some command", lambda: app.dialog.show_dialog("Some command"))

# %%
cmd = t.result()

# %%
str(cmd) in commands.all_commands

# %%
t = app.command_pallet.add(cmd, "An alternate command registry")

# %%
t.result()

# %%
t = app.launcher.add(cmd, "My command")
